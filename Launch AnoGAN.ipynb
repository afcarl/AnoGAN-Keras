# %% [markdown]
# ## 1. Let's import all the libraries

# %%
# https://dpb.bitbucket.io/reloading-modified-code-when-using-the-ipython-interactive-shell.html
# %load_ext autoreload
# %autoreload 1 # from now on, always reload those modules marked with %aimport before executing any Python code

# %%
import os
import sys

os.environ["CUDA_DEVICE_ORDER"]    = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

import numpy as np
np.random.seed(666) # Diabolic Seed is always better :D

from PIL import Image

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# https://dpb.bitbucket.io/reloading-modified-code-when-using-the-ipython-interactive-shell.html
# Autoreloading the library whenever it is changed.
# %aimport anogan 
from anogan import AnoGAN
from random_names import random_name

# %%
flags = tf.app.flags

###############################################################################################################################

# MISC Settings
flags.DEFINE_string("output_dirname", "output", "Target Folder to save images and saved models")

# Input Settings
flags._define_helper("input_shape", (64, 64, 1), "Image Input Shape", list)
flags.DEFINE_integer("batch_size", 64, "The size of batch images [64]")
flags.DEFINE_string("input_dir_training", '../dataset/train/', "Path to the directory containing training data")
flags.DEFINE_string("input_dir_validation", '../dataset/validation/', "Path to the directory containing validation data")

# Latent Shape Definition
flags._define_helper("latent_shape", (100, ), "Size of the latent vector Z", list)

# Network Configuration
flags._define_helper("n_filters", [512, 256, 128, 64], "Convolutions Size for G and D", list)
flags.DEFINE_integer("filter_size", 5, "Kernel Size for the convolutions")
flags.DEFINE_integer("stride", 2, "Kernel Size for the convolutions")
flags.DEFINE_float("gen_lr", 2e-4, "Learning Rate for the Adam Optimizer in G")
flags.DEFINE_float("dis_lr", 2e-4, "Learning Rate for the Adam Optimizer in D")
flags.DEFINE_float("gen_beta1", 0.8, "Beta1 Parameter for the Adam Optimizer in G")
flags.DEFINE_float("dis_beta1", 0.8, "Beta1 Parameter for the Adam Optimizer in D")

# Training Settings
flags.DEFINE_integer("stats_step_interval", 150, "Number of steps between to statistical review of the training")
flags.DEFINE_integer("epochs", 20, "Number of training Epochs to be performed")

###############################################################################################################################

FLAGS = flags.FLAGS

# %%
anogan = AnoGAN(
    input_shape         = FLAGS.input_shape, 
    latent_shape        = FLAGS.latent_shape, 
    n_filters           = FLAGS.n_filters, 
    filter_size         = FLAGS.filter_size,
    strides             = FLAGS.stride,
    gen_lr              = FLAGS.gen_lr, 
    gen_beta1           = FLAGS.gen_beta1, 
    dis_lr              = FLAGS.dis_lr,
    dis_beta1           = FLAGS.dis_beta1,
    model_name          = random_name(sep="_"), 
    output_dirname      = FLAGS.output_dirname,
    stats_step_interval=FLAGS.stats_step_interval
)
# Out:
# Model Name: nifty_nightingale

# %%
anogan.generator_summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8192)              32768
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 8192)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 512)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 512)         6554112
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 256)       3277056
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 128)       819328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 64)        204864
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 1)         1601
# _________________________________________________________________
# generator_output (Activation (None, 64, 64, 1)         0
# =================================================================
# Total params: 11,720,961
# Trainable params: 11,702,657
# Non-trainable params: 18,304
# _________________________________________________________________

# %%
anogan.discriminator_summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         819456
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 512)         3277312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# _________________________________________________________________
# discriminator_output (Activa (None, 1)                 0
# =================================================================
# Total params: 4,315,393
# Trainable params: 4,313,473
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
anogan.full_GAN_summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# model_2 (Model)              (None, 64, 64, 1)         11720961
# _________________________________________________________________
# model_1 (Model)              (None, 1)                 4315393
# =================================================================
# Total params: 16,036,354
# Trainable params: 16,016,130
# Non-trainable params: 20,224
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
    horizontal_flip=True
)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    directory   = FLAGS.input_dir_training,       # this is the target directory
    target_size = FLAGS.input_shape[:-1],         # all images will be resized to 64x64
    batch_size  = FLAGS.batch_size,
    color_mode  = "grayscale",                    # We use a grayscale dataset
    class_mode  = None                            # We do not need to get any label => Everything is healthy
)  

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
    directory   = FLAGS.input_dir_validation,     # this is the target directory
    target_size = FLAGS.input_shape[:-1],         # all images will be resized to 64x64
    batch_size  = FLAGS.batch_size,
    color_mode  = "grayscale",                    # We use a grayscale dataset
    classes     = ["defective", "healthy"],       # {'defective': 0, 'healthy': 1} => Needs to be enforced
    class_mode  = 'binary'                        # We want to have binary labels for validation
)

validation_generator.class_indices
# Out:
# Found 49812 images belonging to 1 classes.
# Found 376 images belonging to 2 classes.
# {'defective': 0, 'healthy': 1}

# %%
anogan.train_generator(
    X_train_generator = train_generator, 
    X_val_generator   = validation_generator,
    epochs            = FLAGS.epochs
)
# Out:
# Epoch 1 of 20
#
# 150/389 [==========>...................] - ETA: 307s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 8.939      | 0.257      |         |            |               |        |
# discriminator (train)               | 0.793      | 0.811      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 112s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 4.831      | 0.450      |         |            |               |        |
# discriminator (train)               | 1.150      | 0.626      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 488s
#
# Epoch processed in 489s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 3.894      | 0.466      |         |            |               |        |
# discriminator (train)               | 1.224      | 0.580      |         |            |               |        |
# detection rate (validation)         |            |            | 0.074   | 0.156      | 0.596         | 0.392  |
#
# ###################################################################################################################
#
# Epoch 2 of 20
#
# 150/389 [==========>...................] - ETA: 293s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.746      | 0.502      |         |            |               |        |
# discriminator (train)               | 1.441      | 0.494      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.744      | 0.501      |         |            |               |        |
# discriminator (train)               | 1.419      | 0.520      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 478s
#
# Epoch processed in 479s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.743      | 0.512      |         |            |               |        |
# discriminator (train)               | 1.412      | 0.526      |         |            |               |        |
# detection rate (validation)         |            |            | 0.021   | 0.174      | 0.899         | 0.479  |
#
# ###################################################################################################################
#
# Epoch 3 of 20
#
# 150/389 [==========>...................] - ETA: 292s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.778      | 0.463      |         |            |               |        |
# discriminator (train)               | 1.370      | 0.578      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.797      | 0.428      |         |            |               |        |
# discriminator (train)               | 1.337      | 0.609      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 479s
#
# Epoch processed in 480s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.803      | 0.416      |         |            |               |        |
# discriminator (train)               | 1.322      | 0.621      |         |            |               |        |
# detection rate (validation)         |            |            | 0.335   | 0.288      | 0.170         | 0.204  |
#
# ###################################################################################################################
#
# Epoch 4 of 20
#
# 150/389 [==========>...................] - ETA: 295s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.920      | 0.281      |         |            |               |        |
# discriminator (train)               | 1.229      | 0.693      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 110s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.938      | 0.287      |         |            |               |        |
# discriminator (train)               | 1.214      | 0.700      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 481s
#
# Epoch processed in 482s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.929      | 0.308      |         |            |               |        |
# discriminator (train)               | 1.227      | 0.690      |         |            |               |        |
# detection rate (validation)         |            |            | 1.000   | 0.507      | 0.027         | 1.000  |
#
# ###################################################################################################################
#
# Epoch 5 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.873      | 0.373      |         |            |               |        |
# discriminator (train)               | 1.282      | 0.641      |         |            |               |        |
#
# ==============================================================================================================
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.916      | 0.334      |         |            |               |        |
# discriminator (train)               | 1.251      | 0.665      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 476s
#
# Epoch processed in 477s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.932      | 0.320      |         |            |               |        |
# discriminator (train)               | 1.257      | 0.666      |         |            |               |        |
# detection rate (validation)         |            |            | 1.000   | 0.518      | 0.069         | 1.000  |
#
# ###################################################################################################################
#
# Epoch 6 of 20
#
# 150/389 [==========>...................] - ETA: 290s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.968      | 0.295      |         |            |               |        |
# discriminator (train)               | 1.265      | 0.664      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.941      | 0.314      |         |            |               |        |
# discriminator (train)               | 1.294      | 0.645      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 476s
#
# Epoch processed in 477s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.930      | 0.323      |         |            |               |        |
# discriminator (train)               | 1.299      | 0.640      |         |            |               |        |
# detection rate (validation)         |            |            | 0.984   | 0.518      | 0.085         | 0.842  |
#
# ###################################################################################################################
#
# Epoch 7 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.918      | 0.322      |         |            |               |        |
# discriminator (train)               | 1.300      | 0.639      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.885      | 0.360      |         |            |               |        |
# discriminator (train)               | 1.326      | 0.618      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 476s
#
# Epoch processed in 478s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.874      | 0.366      |         |            |               |        |
# discriminator (train)               | 1.338      | 0.609      |         |            |               |        |
# detection rate (validation)         |            |            | 0.984   | 0.517      | 0.080         | 0.833  |
#
# ###################################################################################################################
#
# Epoch 8 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.832      | 0.380      |         |            |               |        |
# discriminator (train)               | 1.369      | 0.587      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.817      | 0.403      |         |            |               |        |
# discriminator (train)               | 1.377      | 0.582      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 476s
#
# Epoch processed in 477s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.825      | 0.392      |         |            |               |        |
# discriminator (train)               | 1.366      | 0.592      |         |            |               |        |
# detection rate (validation)         |            |            | 0.564   | 0.493      | 0.420         | 0.491  |
#
# ###################################################################################################################
#
# Epoch 9 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.835      | 0.374      |         |            |               |        |
# discriminator (train)               | 1.344      | 0.604      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.830      | 0.382      |         |            |               |        |
# discriminator (train)               | 1.335      | 0.609      |         |            |               |        |
#
# ==============================================================================================================
# 389/389 [==============================] - 476s
#
# Epoch processed in 477s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.834      | 0.374      |         |            |               |        |
# discriminator (train)               | 1.331      | 0.612      |         |            |               |        |
# detection rate (validation)         |            |            | 0.372   | 0.461      | 0.564         | 0.473  |
#
# ###################################################################################################################
#
# Epoch 10 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.852      | 0.356      |         |            |               |        |
# discriminator (train)               | 1.310      | 0.629      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 108s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.864      | 0.340      |         |            |               |        |
# discriminator (train)               | 1.300      | 0.638      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 475s
#
# Epoch processed in 477s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.858      | 0.348      |         |            |               |        |
# discriminator (train)               | 1.306      | 0.631      |         |            |               |        |
# detection rate (validation)         |            |            | 0.979   | 0.527      | 0.122         | 0.852  |
#
# ###################################################################################################################
#
# Epoch 11 of 20
#
# 150/389 [==========>...................] - ETA: 292s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.880      | 0.323      |         |            |               |        |
# discriminator (train)               | 1.275      | 0.656      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.879      | 0.329      |         |            |               |        |
# discriminator (train)               | 1.279      | 0.652      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 477s
#
# Epoch processed in 478s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.875      | 0.336      |         |            |               |        |
# discriminator (train)               | 1.296      | 0.640      |         |            |               |        |
# detection rate (validation)         |            |            | 0.021   | 0.333      | 0.957         | 0.495  |
#
# ###################################################################################################################
#
# Epoch 12 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.889      | 0.309      |         |            |               |        |
# discriminator (train)               | 1.286      | 0.646      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.910      | 0.292      |         |            |               |        |
# discriminator (train)               | 1.269      | 0.656      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 477s
#
# Epoch processed in 478s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.909      | 0.296      |         |            |               |        |
# discriminator (train)               | 1.269      | 0.655      |         |            |               |        |
# detection rate (validation)         |            |            | 0.415   | 0.446      | 0.484         | 0.453  |
#
# ###################################################################################################################
#
# Epoch 13 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.914      | 0.307      |         |            |               |        |
# discriminator (train)               | 1.256      | 0.665      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.908      | 0.308      |         |            |               |        |
# discriminator (train)               | 1.263      | 0.658      |         |            |               |        |
#
# ==============================================================================================================
#
# 389/389 [==============================] - 477s
#
# Epoch processed in 478s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.917      | 0.303      |         |            |               |        |
# discriminator (train)               | 1.251      | 0.666      |         |            |               |        |
# detection rate (validation)         |            |            | 0.048   | 0.346      | 0.910         | 0.489  |
#
# ###################################################################################################################
#
# Epoch 14 of 20
#
# 150/389 [==========>...................] - ETA: 291s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.929      | 0.300      |         |            |               |        |
# discriminator (train)               | 1.250      | 0.670      |         |            |               |        |
#
# ==============================================================================================================
#
# 300/389 [======================>.......] - ETA: 109s
#
# network                             | loss       | accuracy   | recall  | precision  | specificity   | NPV    |
# --------------------------------------------------------------------------------------------------------------
# generator (train)                   | 0.935      | 0.296      |         |            |               |        |
# discriminator (train)               | 1.240      | 0.675      |         |            |               |        |
#
# ==============================================================================================================
#
# 345/389 [=========================>....] - ETA: 54s

# %% [markdown]
# ### Plot a few sample from the Generator

# %%
generated_images = anogan.generator.generate_samples(batch_size=100, verbose=0)
            
# arrange them into a grid
img = (np.concatenate([r.reshape(-1, 64)
                       for r in np.split(generated_images, 10)
                       ], axis=-1) * 127.5 + 127.5).astype(np.uint8)

Image.fromarray(img)

# %% [markdown]
# ### Plot real data for comparison

# %%
generated_images = np.concatenate([train_generator.next(), train_generator.next()])
generated_images = generated_images[:100]
            
# arrange them into a grid
img = (np.concatenate([r.reshape(-1, 64)
                       for r in np.split(generated_images, 10)
                       ], axis=-1)).astype(np.uint8)

Image.fromarray(img)

# %% [markdown]
# ### Compute Accuracy on Defective Images

# %%
precision, recall, specificity, negative_predictive_value = anogan.detect_defects(validation_generator)

print()
print("Probability of Detecting a Non-Defect             => Recall      (tp / (tp + fn)):", recall)
print("Probability of Correctly Detecting a Non-Defect   => Precision   (tp / (tp + fp)):", precision)
print("Probability of Detecting a Defect                 => Specificity (tn / (tn + fp)):", specificity)
print("Probability of Correctly Detecting a Defect       => NPV         (tn / (tn + fn)):", negative_predictive_value)
